# %%
import config
import polars as pl

pl.Config.set_tbl_cols(100)
pl.Config.set_tbl_rows(100)
pl.Config.set_fmt_str_lengths(500)
# Out:
# polars.config.Config

# %%
train = pl.read_csv(config.COMP_DATASET_DIR / "train.csv", try_parse_dates=True)
test = pl.read_csv(config.COMP_DATASET_DIR / "test.csv", try_parse_dates=True)
sample_submission = pl.read_csv(config.COMP_DATASET_DIR / "sample_submission.csv", try_parse_dates=True)
data_dict = pl.read_csv(config.COMP_DATASET_DIR / "data_dictionary_ja.csv", try_parse_dates=True)

print(f"train: {train.shape}")
print(f"test: {test.shape}")
print(f"sample_submission: {sample_submission.shape}")
print(f"data_dict: {data_dict.shape}")

display(train.head(3))
display(test.head(3))
display(sample_submission.head(3))
display(data_dict.head(3))
# Out:
# train: (28800, 60)
# test: (3, 58)
# sample_submission: (3, 2)
# data_dict: (59, 4)
# shape: (3, 60)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ ID  ┆ dri ┆ psy ┆ cyt ┆ dia ┆ hla ┆ hla ┆ tbi ┆ arr ┆ hla ┆ gra ┆ ven ┆ ren ┆ pul ┆ pri ┆ hla ┆ cmv ┆ hla ┆ hla ┆ tce ┆ hla ┆ hla ┆ rit ┆ hla ┆ hla ┆ pro ┆ cyt ┆ con ┆ eth ┆ yea ┆ obe ┆ mrd ┆ in_ ┆ tce ┆ hla ┆ hep ┆ don ┆ pri ┆ hla ┆ pep ┆ age ┆ hla ┆ gvh ┆ rhe ┆ sex ┆ hla ┆ rac ┆ com ┆ kar ┆ hep ┆ tce ┆ don ┆ mel ┆ hla ┆ car ┆ hla ┆ pul ┆ hla ┆ efs ┆ efs │
# ...

# %%
# targetの把握
print(set(train.columns) - set(test.columns))
# Out:
# {'efs_time', 'efs'}

# %%
train.describe()
# Out:
# shape: (9, 61)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ sta ┆ ID  ┆ dri ┆ psy ┆ cyt ┆ dia ┆ hla ┆ hla ┆ tbi ┆ arr ┆ hla ┆ gra ┆ ven ┆ ren ┆ pul ┆ pri ┆ hla ┆ cmv ┆ hla ┆ hla ┆ tce ┆ hla ┆ hla ┆ rit ┆ hla ┆ hla ┆ pro ┆ cyt ┆ con ┆ eth ┆ yea ┆ obe ┆ mrd ┆ in_ ┆ tce ┆ hla ┆ hep ┆ don ┆ pri ┆ hla ┆ pep ┆ age ┆ hla ┆ gvh ┆ rhe ┆ sex ┆ hla ┆ rac ┆ com ┆ kar ┆ hep ┆ tce ┆ don ┆ mel ┆ hla ┆ car ┆ hla ┆ pul ┆ hla ┆ efs ┆ efs │
# ...

# %%
train["race_group"].unique()
# Out:
# shape: (6,)
# Series: 'race_group' [str]
# [
# 	"White"
# 	"Asian"
# 	"Black or African-American"
# 	"Native Hawaiian or other Pacific Islander"
# 	"American Indian or Alaska Native"
# 	"More than one race"
# ]

# %%
data_dict
# Out:
# shape: (59, 4)
# ┌────────────────────────┬─────────────────────────────┬─────────────┬─────────────────────────────┐
# │ variable               ┆ description                 ┆ type        ┆ values                      │
# │ ---                    ┆ ---                         ┆ ---         ┆ ---                         │
# │ str                    ┆ str                         ┆ str         ┆ str                         │
# ╞════════════════════════╪═════════════════════════════╪═════════════╪═════════════════════════════╡
# │ dri_score              ┆ 精製疾患リスク指数          ┆ Categorical ┆ ['Intermediate' 'High' 'N/A │
# │                        ┆                             ┆             ┆ - non-malignant indication' │
# │                        ┆                             ┆             ┆ 'N/A - pediatric'           │
# │                        ┆                             ┆             ┆ 'High - TED AML case        │
# ...
